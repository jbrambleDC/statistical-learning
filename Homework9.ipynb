# %% [markdown]
# ### Jordan Bramble

# %% [markdown]
# ### Statistical Learning Homework 9

# %% [markdown]
# #### Section 10.7 # 4

# %% [markdown]
# ##### a.

# %% [markdown]
# Since we don't know the intercluster dissimilarities we cannot tell will fusion will be greater ,if either. If the dissimilarities were equal they would fuse at the same height. otherwise single linkage would fuse at a lower height.

# %% [markdown]
# ##### b.

# %% [markdown]
# The height should be the same, given that individual observations are not affected by linkage

# %% [markdown]
# #### Section 10.7 #9

# %%
library(ISLR)
attach(USArrests)

# %% [markdown]
# ##### a.

# %%
plot(hclust(dist(USArrests), method="complete"))
# Out:
# Error in file(con, "rb"): cannot open the connection
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# #### b.

# %%
tree1 <- hclust(dist(USArrests), method='complete')
nxt <- cutree(tree1, 3)
states <- names(nxt)
states[nxt == 1]

states[nxt == 2]

states[nxt == 3]
# Out:
#  [1] "Alabama"        "Alaska"         "Arizona"        "California"
#  [5] "Delaware"       "Florida"        "Illinois"       "Louisiana"
#  [9] "Maryland"       "Michigan"       "Mississippi"    "Nevada"
# [13] "New Mexico"     "New York"       "North Carolina" "South Carolina"
#  [1] "Arkansas"      "Colorado"      "Georgia"       "Massachusetts"
#  [5] "Missouri"      "New Jersey"    "Oklahoma"      "Oregon"
#  [9] "Rhode Island"  "Tennessee"     "Texas"         "Virginia"
# [13] "Washington"    "Wyoming"
#  [1] "Connecticut"   "Hawaii"        "Idaho"         "Indiana"
#  [5] "Iowa"          "Kansas"        "Kentucky"      "Maine"
#  [9] "Minnesota"     "Montana"       "Nebraska"      "New Hampshire"
# [13] "North Dakota"  "Ohio"          "Pennsylvania"  "South Dakota"
# [17] "Utah"          "Vermont"       "West Virginia" "Wisconsin"

# %% [markdown]
# ##### c.

# %%
scaled <- hclust(dist(scale(USArrests)), method="complete")

# %%
plot(scaled)
# Out:
# Error in file(con, "rb"): cannot open the connection
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ##### d.

# %%
table(cutree(scaled,3) == nxt)
# Out:
# FALSE  TRUE
#    22    28

# %% [markdown]
# Scaling the data affects the max height. But scaling the data doesnt affect the results much. The biggest difference is obviously Alaska
