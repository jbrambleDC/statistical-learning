# %% [markdown]
# # Jordan Bramble

# %% [markdown]
# ## Homework 6

# %% [markdown]
# ### Section 7.9 Problem 2

# %% [markdown]
# #### a.

# %% [markdown]
# g^ = 0

# %% [markdown]
# #### b.

# %% [markdown]
# g^ = c

# %% [markdown]
# #### c.

# %% [markdown]
# g^ = ax + b

# %% [markdown]
# ### Section 7.9 Problem 3

# %%
x = -2:2

# %%
y = 1 + x + -2 * (x-1)^2 * I(x>1)

# %%
plot(x,y)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# ### Section 7.9 Problem 6

# %% [markdown]
# #### a.

# %%
library(ISLR)
library(boot)

# %%
cvs = rep(NA, 10)
for (i in 1:10) {
  glm.fit = glm(wage~poly(age, i), data=Wage)
  cvs[i] = cv.glm(Wage, glm.fit, K=10)$delta[2]
}

# %%
plot(1:10, cvs, type="l", ylim=c(1590, 1700))
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %%
min(cvs)
sd(cvs)
# Out:
# [1] 1593.434
# [1] 25.86218

# %% [markdown]
# d = 3, seems to be small and reasonable cv

# %%
fit.1 = lm(wage~poly(age, 1), data=Wage)
fit.2 = lm(wage~poly(age, 2), data=Wage)
fit.3 = lm(wage~poly(age, 3), data=Wage)
fit.4 = lm(wage~poly(age, 4), data=Wage)
fit.5 = lm(wage~poly(age, 5), data=Wage)
fit.6 = lm(wage~poly(age, 6), data=Wage)
fit.7 = lm(wage~poly(age, 7), data=Wage)
fit.8 = lm(wage~poly(age, 8), data=Wage)
fit.9 = lm(wage~poly(age, 9), data=Wage)
fit.10 = lm(wage~poly(age, 10), data=Wage)
anova(fit.1, fit.2, fit.3, fit.4, fit.5, fit.6, fit.7, fit.8, fit.9, fit.10)
# Out:
# Analysis of Variance Table
#
# Model  1: wage ~ poly(age, 1)
# Model  2: wage ~ poly(age, 2)
# Model  3: wage ~ poly(age, 3)
# Model  4: wage ~ poly(age, 4)
# Model  5: wage ~ poly(age, 5)
# Model  6: wage ~ poly(age, 6)
# Model  7: wage ~ poly(age, 7)
# Model  8: wage ~ poly(age, 8)
# Model  9: wage ~ poly(age, 9)
# Model 10: wage ~ poly(age, 10)
#    Res.Df     RSS Df Sum of Sq        F    Pr(>F)
# 1    2998 5022216
# 2    2997 4793430  1    228786 143.7638 < 2.2e-16 ***
# 3    2996 4777674  1     15756   9.9005  0.001669 **
# 4    2995 4771604  1      6070   3.8143  0.050909 .
# 5    2994 4770322  1      1283   0.8059  0.369398
# 6    2993 4766389  1      3932   2.4709  0.116074
# 7    2992 4763834  1      2555   1.6057  0.205199
# 8    2991 4763707  1       127   0.0796  0.777865
# 9    2990 4756703  1      7004   4.4014  0.035994 *
# 10   2989 4756701  1         3   0.0017  0.967529
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# Above 3, they become insignificant

# %%
plot(wage~age, data=Wage, col="green")
ageRange = range(Wage$age)
ageSeq = seq(from=ageRange[1], to=ageRange[2])
lm.fit = lm(wage~poly(age, 3), data=Wage)
lm.pred = predict(lm.fit, data.frame(age=ageSeq))
lines(ageSeq, lm.pred, col="blue", lwd=2)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# ### Section 7.9 Problem 9

# %% [markdown]
# #### a.

# %%
library(MASS)
attach(Boston)

# %%
fit = lm(nox~poly(dis,3),data = Boston)
summary(fit)
# Out:
# Call:
# lm(formula = nox ~ poly(dis, 3), data = Boston)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121130 -0.040619 -0.009738  0.023385  0.194904
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.554695   0.002759 201.021  < 2e-16 ***
# poly(dis, 3)1 -2.003096   0.062071 -32.271  < 2e-16 ***
# poly(dis, 3)2  0.856330   0.062071  13.796  < 2e-16 ***
# poly(dis, 3)3 -0.318049   0.062071  -5.124 4.27e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06207 on 502 degrees of freedom
# Multiple R-squared:  0.7148,	Adjusted R-squared:  0.7131
# F-statistic: 419.3 on 3 and 502 DF,  p-value: < 2.2e-16

# %%
distRes = seq(from = range(dis)[1], to = range(dis)[2], by = 0.1)
pred = predict(fit, list(dis = distRes))

# %%
plot(nox ~ dis, data = Boston)
lines(distRes, pred, col = "red", lwd = 2)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# #### b.

# %%
for(i in 1:10){
    fit = lm(nox~poly(dis,i),data = Boston)
    output = paste(c("Degree: ", as.character(i), "RSS:",as.character(sum(fit$residuals^2))))
    print(output)
    }
# Out:
# [1] "Degree: "         "1"                "RSS:"             "2.76856285896928"
# [1] "Degree: "         "2"                "RSS:"             "2.03526186893526"
# [1] "Degree: "         "3"                "RSS:"             "1.93410670717907"
# [1] "Degree: "         "4"                "RSS:"             "1.93298132729859"
# [1] "Degree: "        "5"               "RSS:"            "1.9152899610843"
# [1] "Degree: "         "6"                "RSS:"             "1.87825729850816"
# [1] "Degree: "         "7"                "RSS:"             "1.84948361458298"
# [1] "Degree: "         "8"                "RSS:"             "1.83562968906769"
# [1] "Degree: "        "9"               "RSS:"            "1.8333308044916"
# [1] "Degree: "         "10"               "RSS:"             "1.83217112393138"

# %% [markdown]
# ### Section 7.9 Problem 11

# %% [markdown]
# #### a.

# %%
e = rnorm(1000)
x1 = rnorm(1000)
x2 = rnorm(1000)
y = x1 + 2*x2 + e

# %% [markdown]
# #### b.

# %%
beta1 = 3

# %% [markdown]
# #### c.

# %%
a = y - beta1*x1
beta2 = lm(a~x2)$coef[2]

# %% [markdown]
# #### d

# %%
a=y-beta2*x2
beta1=lm(a~x1)$coef[2]
beta0=lm(a~x1)$coef[1]

# %% [markdown]
# #### e

# %%
beta1s = rep(beta1,1000)
beta2s = rep(beta2,1000)
beta0s = rep(beta0,1000)
for(i in 2:1000){
    a=y-beta1*x1
    beta2=lm(a~x2)$coef[2]
    beta2s[i] = beta2
    a=y-beta2*x2
    beta1=lm(a~x1)$coef[2]
    beta1s[i] = beta1
    beta0=lm(a~x1)$coef[1]
    beta0s[i] = beta0
    }

# %%
summary(beta1s)
unique(beta1s)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.9430  0.9430  0.9430  0.9430  0.9430  0.9505
# [1] 0.9504676 0.9430159 0.9429888 0.9429887 0.9429887 0.9429887 0.9429887
# [8] 0.9429887

# %%
summary(beta2s)
unique(beta2s)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.842   1.960   1.960   1.960   1.960   1.960
# [1] 1.842045 1.959771 1.960199 1.960200 1.960200 1.960200 1.960200 1.960200

# %%
summary(beta0s)
unique(beta0s)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.02472 0.02472 0.02472 0.02473 0.02472 0.02721
# [1] 0.02721391 0.02473303 0.02472401 0.02472397 0.02472397 0.02472397 0.02472397
# [8] 0.02472397

# %% [markdown]
# #### f.

# %%
fit = lm(y~x1+x2)
summary(fit)
# Out:
# Call:
# lm(formula = y ~ x1 + x2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.5249 -0.6991 -0.0543  0.7226  3.1480
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02472    0.03204   0.772    0.441
# x1           0.94299    0.03335  28.273   <2e-16 ***
# x2           1.96020    0.03177  61.696   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.013 on 997 degrees of freedom
# Multiple R-squared:  0.829,	Adjusted R-squared:  0.8287
# F-statistic:  2417 on 2 and 997 DF,  p-value: < 2.2e-16

# %% [markdown]
# These coefficients are quite close to those shown in part e!!
