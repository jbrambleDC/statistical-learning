# %% [markdown]
# # Jordan Bramble
# ## Statistical Learning Homework 1

# %% [markdown]
# ### 2.4 Problem 2

# %% [markdown]
# a. This is a regression problem, given that we are dealing with a continuous numerical quanitity (salary).
# We are interested mainly in inference given that we are focused on determining which variables have the greatest effect and not on predicting a salary given some variable set. salary is the predicted variable , profit, number of employees, and industry are explanatory variables.

# %% [markdown]
# b. this is a classification problem (success or failure). we are interested in prediction, given the goal is to predict an outcome for a new product. price, competition price, marketing budget are explanatory variables.

# %% [markdown]
# c. This is a regression problem, we are interested in predicting a percentage change in US dollar, given a percentage change in some other currencies. percent change in currencies are the explanatory varaibles. US dollar percent change is being predicted.

# %% [markdown]
# ### 2.4 Problem 4

# %% [markdown]
# a. Example one; Classifying news articles as (Conservative, Liberal, Libertarian, None) based on text, the predictors are the sentences composing the articles. We are interested in Prediction, however if the goal is understanding what sentence features or structure contribute to each classification then we would be interested in inference
#
# Example Two; Classifying Yelp reviews as either good or bad (Response), or 1-5 stars. Understanding what sentence features, bigram pairs or trigram triplets as strong indicators of a given review score. The sentences are predictors. This would be inference.
#
# Example Three; We can take real estate costs, school rankings, average household income, rate of single family house holds (Predictors) and classify a neighborhood as (Least Desirable, Less Desirable, Desirable, More Desirable, Most Desirable) to live. This would be a prediction problem. We would need a training set, of some neighborhoods or zipcodes that already have these classifications, through some survey statistic.

# %% [markdown]
# b. Example one; Given some stock performance in a given industry, percentage changes, news reactions (Predictors), predict a percentage change in the stock market ( Response) this is a prediction problem.
#
# Example two; Given some indicators of human development for the years 1970-2015 for a set of countries, such as (infant mortality, life expectancy, education, percent access to clean drinking water, AIDS rate) Predict a human development index for future years. This is a prediction problem. If we wanted to understand what years are the greatest predictors, of what factors (Life expectanct, education ,etc) are the best predictors of the response (human development index), then that would be an inference problem.
#
# Example three; if we wanted to predict average monthly sales (response) at a restaurant, given marketing budget (predictor) That would be a prediction problem

# %% [markdown]
# c. Example one; If we know the average energy usage (predictor) of millions of utility customers at a given time over 24 hours, we can cluster them into archetypes (response). an example archetype would be a night-owl, low usage in the morning but heavy usage at night.
#
# Example two; If we know the temperature and Luminosity (Predictors) of a dataset of stars, we can cluster them into spectral classifications such as (Red Dwarf, White Dwarf, Red Giant, etc) (Response). See below image:
#   <img src="Hertzsprung-Russel_StarData.png">
#
# Example three; We can use Clustering to do Topical Modeling of textual documents. Based on text in each document, cluster them into a given number of clusters, figure out what these clusters have in common and create a "topic" for each cluster.

# %% [markdown]
# ### 2.4 Problem 7

# %%
data = data.frame(X1=c(0, 2, 0, 0, -1, 1), X2=c(3, 0, 1, 1, 0, 1), X3=c(0, 0, 3, 2, 1, 1), Y=c("Red", "Red", "Red", "Green", "Green", "Red"))

# %%
data
# Out:
#   X1 X2 X3     Y
# 1  0  3  0   Red
# 2  2  0  0   Red
# 3  0  1  3   Red
# 4  0  1  2 Green
# 5 -1  0  1 Green
# 6  1  1  1   Red

# %%
# a.
dist_data <- data[,c('X1','X2','X3')]
new_row <- c(0, 0, 0)
dist_data <- rbind(dist_data, new_row)
dist(dist_data, method='euclidean')
# Out:
#          1        2        3        4        5        6
# 2 3.605551
# 3 3.605551 3.741657
# 4 2.828427 3.000000 1.000000
# 5 3.316625 3.162278 2.449490 1.732051
# 6 2.449490 1.732051 2.236068 1.414214 2.236068
# 7 3.000000 2.000000 3.162278 2.236068 1.414214 1.732051

# %% [markdown]
# in row 7, we see he distance between all of the other vectors.

# %% [markdown]
# b. With K=1, running kNN our closest vector is 5, which has Y= "Green", so we would assign Green.
#
# c. With K=3, our three closest vectors are 5,6,2. So we have 1 Green and 2 Red, therefore we would assign Red.
#
# d. The Higher we make K, the more linear the decision boudnary will be. We would expect k to be lower to fit more irregular data.

# %% [markdown]
# ### 2.4 Problem 9

# %%
library(ISLR)

# %%
# import Auto data
data(Auto)
Auto = na.omit(Auto)
Auto = Auto[!is.null(Auto),]
summary(Auto)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#
#   acceleration        year           origin                      name
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000   amc matador       :  5
#  1st Qu.:13.78   1st Qu.:73.00   1st Qu.:1.000   ford pinto        :  5
#  Median :15.50   Median :76.00   Median :1.000   toyota corolla    :  5
#  Mean   :15.54   Mean   :75.98   Mean   :1.577   amc gremlin       :  4
#  3rd Qu.:17.02   3rd Qu.:79.00   3rd Qu.:2.000   amc hornet        :  4
#  Max.   :24.80   Max.   :82.00   Max.   :3.000   chevrolet chevette:  4
#                                                  (Other)           :365

# %%
head(Auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1  18         8          307        130   3504         12.0   70      1
# 2  15         8          350        165   3693         11.5   70      1
# 3  18         8          318        150   3436         11.0   70      1
# 4  16         8          304        150   3433         12.0   70      1
# 5  17         8          302        140   3449         10.5   70      1
# 6  15         8          429        198   4341         10.0   70      1
#                        name
# 1 chevrolet chevelle malibu
# 2         buick skylark 320
# 3        plymouth satellite
# 4             amc rebel sst
# 5               ford torino
# 6          ford galaxie 500

# %% [markdown]
# a.
# Quantitative: (mpg, displacement, horsepower, weight, acceleration)
#
# Qualitative: (year, origin, name, cylinders)
#
# b. We can look at the above summary to get the ranges, without using the range function. Or we can do the below:

# %%
quantitative = c("mpg", "displacement", "horsepower", "weight", "acceleration")
qual <- c('year', 'origin', 'name', 'cylinders')
for(i in quantitative){
    print(i)
    print(range(Auto[, i]))
    }
# Out:
# [1] "mpg"
# [1]  9.0 46.6
# [1] "displacement"
# [1]  68 455
# [1] "horsepower"
# [1]  46 230
# [1] "weight"
# [1] 1613 5140
# [1] "acceleration"
# [1]  8.0 24.8

# %% [markdown]
# c.

# %%
for(i in quantitative){
    print(i)
    print(mean(Auto[, i]))
    print(sd(Auto[, i]))    
    }
# Out:
# [1] "mpg"
# [1] 23.44592
# [1] 7.805007
# [1] "displacement"
# [1] 194.412
# [1] 104.644
# [1] "horsepower"
# [1] 104.4694
# [1] 38.49116
# [1] "weight"
# [1] 2977.584
# [1] 849.4026
# [1] "acceleration"
# [1] 15.54133
# [1] 2.758864

# %% [markdown]
# d.

# %%
sub.Auto = Auto[-c(10:85),]
for(i in quantitative){
    print(i)
    print(range(sub.Auto[, i]))
    print(mean(sub.Auto[, i]))
    print(sd(sub.Auto[, i]))    
    }
# Out:
# [1] "mpg"
# [1] 11.0 46.6
# [1] 24.40443
# [1] 7.867283
# [1] "displacement"
# [1]  68 455
# [1] 187.2405
# [1] 99.67837
# [1] "horsepower"
# [1]  46 230
# [1] 100.7215
# [1] 35.70885
# [1] "weight"
# [1] 1649 4997
# [1] 2935.972
# [1] 811.3002
# [1] "acceleration"
# [1]  8.5 24.8
# [1] 15.7269
# [1] 2.693721

# %% [markdown]
# e.

# %%
pairs(Auto[,quantitative])
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# f.

# %% [markdown]
# We can generally see that displacement, weight, and horsepower all have a negative exponential relationship with mpg, and see that as those features increase, mpg decreases. Acceleration is much more spread out and does not quite follow a trend that is predictable. Acceleration is probably not a good predictor of mpg.

# %% [markdown]
# ### 2.4 Problem 10

# %% [markdown]
# a.

# %%
library(MASS)

# %%
?Boston
# Out:
# Boston                  package:MASS                   R Documentation
#
# n
#
# n:
#
#      The ‘Boston’ data frame has 506 rows and 14 columns.
#
# e:
#
#      Boston
#
# t:
#
#      This data frame contains the following columns:
#
#      ‘crim’ per capita crime rate by town.
#
#      ‘zn’ proportion of residential land zoned for lots over 25,000
#           sq.ft.
#
#      ‘indus’ proportion of non-retail business acres per town.
#
#      ‘chas’ Charles River dummy variable (= 1 if tract bounds river; 0
#           otherwise).
#
#      ‘nox’ nitrogen oxides concentration (parts per 10 million).
#
#      ‘rm’ average number of rooms per dwelling.
#
#      ‘age’ proportion of owner-occupied units built prior to 1940.
#
#      ‘dis’ weighted mean of distances to five Boston employment
#           centres.
#
#      ‘rad’ index of accessibility to radial highways.
#
#      ‘tax’ full-value property-tax rate per \$10,000.
#
#      ‘ptratio’ pupil-teacher ratio by town.
#
#      ‘black’ 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by
#           town.
#
#      ‘lstat’ lower status of the population (percent).
#
#      ‘medv’ median value of owner-occupied homes in \$1000s.
#
# e:
#
#      Harrison, D. and Rubinfeld, D.L. (1978) Hedonic prices and the
#      demand for clean air.  _J. Environ. Economics and Management_ *5*,
#      81-102.
#
#      Belsley D.A., Kuh, E.  and Welsch, R.E. (1980) _Regression
#      Diagnostics. Identifying Influential Data and Sources of
#      Collinearity._ New York: Wiley.

# %% [markdown]
# clearly we see there are 506 rows and 14 columns.

# %% [markdown]
# b & c.

# %%
pairs(Boston)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# surprisingly crime seems to be higher as the distance from employment centers decreases. the opposite is true for crime vs age, as age increases crime increases. there seems to be a negative relationship between lstat and medv. nox levels seem to decrease as distance increases.

# %% [markdown]
# d.

# %%
quantile(Boston$crim, seq(from = 0, to = 1, by = .1))
hist(Boston$crim, breaks = 25)
# Out:
#        0%       10%       20%       30%       40%       50%       60%       70%
#  0.006320  0.038195  0.064170  0.099245  0.150380  0.256510  0.550070  1.728440
#       80%       90%      100%
#  5.581070 10.753000 88.976200
# Error in file(con, "rb"): cannot open the connection
# Plot with title “Histogram of Boston$crim”

# %% [markdown]
# we can see that for crime rates most are very low, but the tail is extremely long, some are more than 80 times higher than the mean

# %%
quantile(Boston$tax)
hist(Boston$tax, breaks = 25)
# Out:
#   0%  25%  50%  75% 100%
#  187  279  330  666  711
# Error in file(con, "rb"): cannot open the connection
# Plot with title “Histogram of Boston$tax”

# %% [markdown]
# there are more than 120 suburbs outside of the distribution with very high tax rates

# %%
quantile(Boston$ptratio)
hist(Boston$ptratio, breaks = 10)
# Out:
#    0%   25%   50%   75%  100%
# 12.60 17.40 19.05 20.20 22.00
# Error in file(con, "rb"): cannot open the connection
# Plot with title “Histogram of Boston$ptratio”

# %% [markdown]
# We can see that the highest bin of pupil teacher ratio is concentraded just above the mean. there are a sizeable number of neighborhoods spread out below the mean with the min being 12. I am asusming the lower ratio the better.

# %% [markdown]
# e.

# %%
sum(Boston$chas == 1)
# Out:
# [1] 35

# %% [markdown]
# f.

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# g.

# %%
Boston[Boston$medv == min(Boston$medv),]
# Out:
#        crim zn indus chas   nox    rm age    dis rad tax ptratio  black lstat
# 399 38.3518  0  18.1    0 0.693 5.453 100 1.4896  24 666    20.2 396.90 30.59
# 406 67.9208  0  18.1    0 0.693 5.683 100 1.4254  24 666    20.2 384.97 22.98
#     medv
# 399    5
# 406    5

# %% [markdown]
# notice that the crime rates are extremely high, approaching the max. also notice the age is quite high. 100% of homes were built prior to 1940. Tax rates are also double

# %% [markdown]
# h.

# %%
nrow(Boston[Boston$rm > 7,])
nrow(Boston[Boston$rm > 8,])
summary(Boston[Boston$rm>8,])
# Out:
# [1] 64
# [1] 13
#       crim               zn            indus             chas
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   Min.   :0.0000
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1st Qu.:0.0000
#  Median :0.52014   Median : 0.00   Median : 6.200   Median :0.0000
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078   Mean   :0.1538
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200   3rd Qu.:0.0000
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580   Max.   :1.0000
#       nox               rm             age             dis
#  Min.   :0.4161   Min.   :8.034   Min.   : 8.40   Min.   :1.801
#  1st Qu.:0.5040   1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288
#  Median :0.5070   Median :8.297   Median :78.30   Median :2.894
#  Mean   :0.5392   Mean   :8.349   Mean   :71.54   Mean   :3.430
#  3rd Qu.:0.6050   3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652
#  Max.   :0.7180   Max.   :8.780   Max.   :93.90   Max.   :8.907
#       rad              tax           ptratio          black
#  Min.   : 2.000   Min.   :224.0   Min.   :13.00   Min.   :354.6
#  1st Qu.: 5.000   1st Qu.:264.0   1st Qu.:14.70   1st Qu.:384.5
#  Median : 7.000   Median :307.0   Median :17.40   Median :386.9
#  Mean   : 7.462   Mean   :325.1   Mean   :16.36   Mean   :385.2
#  3rd Qu.: 8.000   3rd Qu.:307.0   3rd Qu.:17.40   3rd Qu.:389.7
#  Max.   :24.000   Max.   :666.0   Max.   :20.20   Max.   :396.9
#      lstat           medv
#  Min.   :2.47   Min.   :21.9
#  1st Qu.:3.32   1st Qu.:41.7
#  Median :4.14   Median :48.3
#  Mean   :4.31   Mean   :44.2
#  3rd Qu.:5.12   3rd Qu.:50.0
#  Max.   :7.44   Max.   :50.0

# %% [markdown]
# We can see that this reduces the crime rate quite a bit. this also reduces the median pt ratio. and less are bordering the charles river.
