# %% [markdown]
# ## Jordan Bramble

# %% [markdown]
# ### Statistical Learning

# %% [markdown]
# ### Homework 3

# %% [markdown]
# #### 3.7 Problem 10

# %% [markdown]
# ##### a.

# %%
library(ISLR)

# %%
data(Carseats)

# %%
head(Carseats)
# Out:
#   Sales CompPrice Income Advertising Population Price ShelveLoc Age Education
# 1  9.50       138     73          11        276   120       Bad  42        17
# 2 11.22       111     48          16        260    83      Good  65        10
# 3 10.06       113     35          10        269    80    Medium  59        12
# 4  7.40       117    100           4        466    97    Medium  55        14
# 5  4.15       141     64           3        340   128       Bad  38        13
# 6 10.81       124    113          13        501    72       Bad  78        16
#   Urban  US
# 1   Yes Yes
# 2   Yes Yes
# 3   Yes Yes
# 4   Yes Yes
# 5   Yes  No
# 6    No Yes

# %%
attach(Carseats)
model = lm(Sales~Price+Urban+US)
summary(model)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# ##### b.

# %% [markdown]
# We can analyze the P-vals to see that there is a relationship between Price, related to sales. in this case the relationship is negative. As Price increases, Sales Decrease. Thereis no relationship between UrbanYes and sales, however with USYes there is. This relationship is positive. If a store is in the US, sales will increase.

# %% [markdown]
# ##### c.

# %% [markdown]
# Sales = 13.04 + -0.05 Price + -0.02 UrbanYes + 1.20 USYes

# %% [markdown]
# or: Sales = 13.04 + -0.05 Price + 1.20 USYes if we neglect UrbanYes

# %% [markdown]
# ##### d.

# %% [markdown]
# We sort of touched on this in part b, but based on p values and F-statistic, we can reject for Price and USYes

# %% [markdown]
# ##### e.

# %%
attach(Carseats)
model = lm(Sales~Price+US)
summary(model)
# Out:
# The following objects are masked from Carseats (pos = 3):
#
#     Advertising, Age, CompPrice, Education, Income, Population, Price,
#     Sales, ShelveLoc, Urban, US
# Call:
# lm(formula = Sales ~ Price + US)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# ##### g.

# %%
confint(model)
# Out:
#                   2.5 %      97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %% [markdown]
# ##### h.

# %%
par(mfrow = c(2,2))
plot(model)
# Out:
# Error in file(con, "rb"): cannot open the connection
# Plot with title “”

# %%
plot(predict(model), rstudent(model))
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# since the studentized residuals are bound by -3 to 3 there is no suggestion of outliers. We also notice a few points that seem to have high leverage, pulling the leverage plot.

# %% [markdown]
# #### 4.7 Problem 2

# %% [markdown]
# $$p_{k}(x)=\frac{\pi_{k}*\frac{1}{\sqrt{2\pi}\sigma}exp\left\{ -\frac{1}{2\sigma^{2}}\left(x-u_{k}\right)^{2}\right\} }{\sum_{i=1}^{K}\pi_{i}*\frac{1}{\sqrt{2\pi}\sigma}exp\left\{ -\frac{1}{2\sigma^{2}}\left(x-u_{i}\right)^{2}\right\} }$$
#
# $$\delta_{k}(x)=x*\frac{\mu_{k}}{\sigma^{2}}-\frac{\mu_{k}^{2}}{2\sigma^{2}}+log(\pi_{k})$$
#
#
# $log\left(\pi_{k}*\frac{1}{\sqrt{2\pi}\sigma}exp\left\{ -\frac{1}{2\sigma^{2}}\left(x-u_{k}\right)^{2}\right\} \right)=log(\pi_{k})+log\left(\frac{1}{\sqrt{2\pi}\sigma}exp\left\{ -\frac{1}{2\sigma^{2}}\left(x-u_{k}\right)^{2}\right\} \right)=log(\pi_{k})+log(\frac{1}{\sqrt{2\pi}\sigma})*( -\frac{1}{2\sigma^{2}}\left(x-u_{k}\right)^{2})$
#
#
# $log(\pi_{k})+-\frac{1}{2\sigma^{2}}\left(x^{2}-2xu_{k}+\mu_{k}^{2}\right)$
#
#
# $log(\pi_{k})+-\frac{1}{2\sigma^{2}}\left(-2xu_{k}+\mu_{k}^{2}\right)=log(\pi_{k})-\frac{1}{2\sigma^{2}}*-2xu_{k}-\frac{1}{2\sigma^{2}}*\mu_{k}^{2}$
#
# This is the same as:
# $$\delta_{k}(x)=x*\frac{\mu_{k}}{\sigma^{2}}-\frac{\mu_{k}^{2}}{2\sigma^{2}}+log(\pi_{k})$$

# %% [markdown]
# ### 4.7 Problem 5

# %% [markdown]
# ##### a.

# %% [markdown]
# we can expect the QDA to always fit better in training given that it always captures complexity better. However, the Linear model should perform better in test because the QDA could easily overfit given that the true boundary is linear.

# %% [markdown]
# ##### b.

# %% [markdown]
# once again QDA will always perform better in train. We could also in this case expect QDA to perform better in test, but it will depend on the degree of non linearity.

# %% [markdown]
# ##### c.

# %% [markdown]
# We can expect test accuracy of QDA to improve relative to LDA as sample size increases, mainly due to the greter complexity that QDA can manage. However, in terms of model generalization it will ultimately depend on the decision boundary and the shape of the data it self.

# %% [markdown]
# ##### d.

# %% [markdown]
# False. Depends on the sample size. if sample size is small QDA will be prone to overfitting.

# %% [markdown]
# #### 4.7 Problem 6

# %% [markdown]
# ##### a.

# %% [markdown]
# P(Y = 1 | X1 = 40, X2 = 3.5) = exp(-6 + .05x40 + 1x3.5)/(1 + exp(-6 + .05x40 + 1x3.5)) =~ .3775

# %% [markdown]
# ##### b.

# %% [markdown]
# .5 = exp(-6 + .05X +  3.5)/(1 + exp(-6 + .05X + 3.5))
# .5 + .5exp(-2.5 + .05X) = exp(-2.5 + .05X)
# 1 = exp(-2.5 + .05X)
# given a natural log
# 0 = -2.5 + .05X
# 2.5/.05 = X
# 50 hours would be needed!

# %% [markdown]
# ### 4.7 Problem 11

# %%
library(ISLR)
data(Auto)

# %% [markdown]
# ##### a.

# %%
Auto$mpg01 = rep(0, times = nrow(Auto))
Auto$mpg01[Auto$mpg>median(Auto$mpg)] = 1

# %%
head(Auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1  18         8          307        130   3504         12.0   70      1
# 2  15         8          350        165   3693         11.5   70      1
# 3  18         8          318        150   3436         11.0   70      1
# 4  16         8          304        150   3433         12.0   70      1
# 5  17         8          302        140   3449         10.5   70      1
# 6  15         8          429        198   4341         10.0   70      1
#                        name mpg01
# 1 chevrolet chevelle malibu     0
# 2         buick skylark 320     0
# 3        plymouth satellite     0
# 4             amc rebel sst     0
# 5               ford torino     0
# 6          ford galaxie 500     0

# %%
Auto[Auto$mpg01==1,]

# %% [markdown]
# ##### b.

# %%
cor(Auto[, -9])
# Out:
#                     mpg  cylinders displacement horsepower     weight
# mpg           1.0000000 -0.7776175   -0.8051269 -0.7784268 -0.8322442
# cylinders    -0.7776175  1.0000000    0.9508233  0.8429834  0.8975273
# displacement -0.8051269  0.9508233    1.0000000  0.8972570  0.9329944
# horsepower   -0.7784268  0.8429834    0.8972570  1.0000000  0.8645377
# weight       -0.8322442  0.8975273    0.9329944  0.8645377  1.0000000
# acceleration  0.4233285 -0.5046834   -0.5438005 -0.6891955 -0.4168392
# year          0.5805410 -0.3456474   -0.3698552 -0.4163615 -0.3091199
# origin        0.5652088 -0.5689316   -0.6145351 -0.4551715 -0.5850054
# mpg01         0.8369392 -0.7591939   -0.7534766 -0.6670526 -0.7577566
#              acceleration       year     origin      mpg01
# mpg             0.4233285  0.5805410  0.5652088  0.8369392
# cylinders      -0.5046834 -0.3456474 -0.5689316 -0.7591939
# displacement   -0.5438005 -0.3698552 -0.6145351 -0.7534766
# ...

# %%
pairs(Auto)
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %% [markdown]
# Visualizations dont neccesarily work well because we have a binary variable. but cylinders, horsepower, weight, and weight are solid predcitors.

# %% [markdown]
# ##### c.

# %%
training = sample(x = nrow(Auto), size = 0.5*nrow(Auto),replace = F)
training.set = Auto[training,]
test.set = Auto[-training,-10]

# %% [markdown]
# #### d.

# %%
library(MASS)
lda.auto = lda(mpg01~cylinders+displacement+horsepower+weight, data = training.set[,-9])

# %%
lda.predict = predict(lda.auto, test.set)
mean(lda.predict$class != Auto[-training,10])
# Out:
# [1] 0.127551

# %% [markdown]
# error rate around 12.7 percent

# %% [markdown]
# ##### e.

# %%
qda.auto = qda(mpg01~cylinders+displacement+horsepower+weight, data = training.set[,-9])

# %%
qda.predict = predict(qda.auto, test.set)
mean(qda.predict$class != Auto[-training,10])
# Out:
# [1] 0.1428571

# %% [markdown]
# about 14% error rate in test

# %% [markdown]
# ##### f.

# %%
logit.auto = glm(mpg01~cylinders+displacement+horsepower+weight,data = training.set[,-9], family = binomial)

# %%
logit.pred = predict(logit.auto, test.set,type="response")
logit.pred = rep(0, times = length(logit.pred))
logit.pred[logit.pred>0.5] = 1
mean(logit.pred != Auto[-training,10])
# Out:
# [1] 0.5102041

# %% [markdown]
# ##### g.

# %%
ks = 1:15
library(FNN)
k.results = data.frame(ks, error = ks)
for(i in ks){
    knn.predict = knn(train = training.set[,c("cylinders","displacement","horsepower","weight")], 
        test = test.set[,c("cylinders","displacement","horsepower","weight")], cl = training.set$mpg01, k = i)
    k.results[k.results$ks == i, "error"]=mean(knn.predict != Auto[-training,10])
}
k.results
# Out:
#    ks     error
# 1   1 0.1581633
# 2   2 0.1785714
# 3   3 0.1326531
# 4   4 0.1530612
# 5   5 0.1326531
# 6   6 0.1428571
# 7   7 0.1377551
# 8   8 0.1428571
# 9   9 0.1428571
# 10 10 0.1428571
# 11 11 0.1428571
# 12 12 0.1377551
# 13 13 0.1428571
# 14 14 0.1428571
# 15 15 0.1479592

# %% [markdown]
# seems that 12 is the optimal number of neighbors to use. though 3, or 7 give similar results
